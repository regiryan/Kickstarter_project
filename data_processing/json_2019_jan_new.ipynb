# %%
import pandas as pd
pd.set_option('display.max_columns', 500)
from datetime import datetime
import numpy as np
import timeit
import json

# %%
start_time = timeit.default_timer()


df_2019_jan = pd.read_json('json_datasets/Kickstarter_2019-01-17T03_20_02_630Z.json', lines=True)


elapsed = timeit.default_timer() - start_time
print(f'time: {elapsed}')
# Out:
# time: 463.13942923699994

# %%
# Save the creation datetime for calculating age of project later
df_2019_jan_collected_on = datetime(2019, 1, 17)

# %%
# clean up the format and make a deep copy
# start_time = timeit.default_timer()


df_2019_jan = df_2019_jan['data'].apply(pd.Series)
# df_2019_jan_copy = df_2019_jan.copy(deep=True)
print(f'Total_rows: {len(df_2019_jan)}')


# elapsed = timeit.default_timer() - start_time
# print(f'time: {elapsed}')

df_2019_jan.head(3)
# Out:
# Total_rows: 207848
#            id                                              photo  \
# 0   320897621  {'key': 'assets/013/884/141/51d672393d941b28a9...
# 1  1504102568  {'key': 'assets/012/061/827/c4a4d3b58093abe6a7...
# 2   284827571  {'key': 'assets/018/209/038/4d46d6bed9b83d4e9a...
#
#                                           name  \
# 0  A Date in 2025 - A sci-fi comedy short film
# 1       Replacement Place | New York Live Arts
# 2                          Pumpkin Spice Love!
#
#                                                blurb    goal  pledged  \
# 0  In the year 2025, a young man's superintellige...  4000.0  5265.82
# 1  Replacement Place needs your support to combat...  5000.0  5225.00
# 2  Pumpkin Spice Love - A Pumpkin Spice 4 Life 30...   250.0   362.00
#
#         state                                       slug  \
# 0  successful  a-date-in-2025-a-sci-fi-comedy-short-film
# 1  successful       replacement-place-new-york-live-arts
# ...

# %%
# # Check if data has same features
# df_2019_jan_cols = df_2019_jan.columns
# columns_original  = ['id', 'photo', 'name', 'blurb', 'goal', 'pledged', 'state', 'slug', 'disable_communication', 'country', 'country_displayable_name', 'currency', 'currency_symbol', 'currency_trailing_code', 'deadline', 'state_changed_at', 'created_at', 'launched_at', 'staff_pick', 'is_starrable', 'backers_count', 'static_usd_rate', 'usd_pledged', 'converted_pledged_amount', 'fx_rate', 'current_currency', 'usd_type', 'creator', 'location', 'category', 'profile', 'spotlight', 'urls', 'source_url', 'friends', 'is_starred', 'is_backing', 'permissions']
# diff = list(set(df_2019_jan_cols) - set(columns_original))
# diff2 = list(set(columns_original) - set(df_2019_jan_cols))
# print(diff)
# print(diff2)

# %%
# # inspect canceled and suspended states
# df_2019_jan.state.value_counts()

# %%
# drop canceled and suspended states
df_2019_jan.drop((df_2019_jan[((df_2019_jan.state == 'suspended') | 
                                         (df_2019_jan.state == 'canceled'))].index), inplace=True)

# check for duplicates
print(f"Rows with duplicate project_id: {df_2019_jan.duplicated(['id']).sum()}")

# drop duplicates
df_2019_jan.drop_duplicates(['id'], inplace=True)
print(f'Total_rows after dropping duplicates and suspended/canceled states: {len(df_2019_jan)}')
# Out:
# Rows with duplicate project_id: 26914
# Total_rows after dropping duplicates and suspended/canceled states: 171630

# %%
# # get links to project and creator pages
# start_time = timeit.default_timer()


# df_2019_jan['project_link'] = 'no_val'
# project_link_loc = df_2019_jan.columns.get_loc('project_link')
# for n in range(len(df_2019_jan)):
#     project_link = df_2019_jan.iloc[n].urls['web']['project']
#     df_2019_jan.iat[n, project_link_loc] = project_link
    
# df_2019_jan['creator_link'] = 'no_val'
# creator_link_loc = df_2019_jan.columns.get_loc('creator_link')
# for n in range(len(df_2019_jan)):
#     creator_link = df_2019_jan.iloc[n].creator['urls']['web']['user']
#     df_2019_jan.iat[n, creator_link_loc] = creator_link  
    
    
# elapsed = timeit.default_timer() - start_time
# print(f'time: {elapsed}')

# %%
# # get main_category id
# start_time = timeit.default_timer()


# categories_map = {1:'Art',3:'Comics', 17:'Theater', 15:'Photography', 
#                 7:'Design', 6: 'Dance', 11:'Film & Video', 12:'Games', 16:'Technology', 
#                 13:'Journalism', 18:'Publishing', 9:'Fashion', 10:'Food', 14:'Music', 26:'Crafts'}
# categories_df = pd.DataFrame(categories_map, index=[0])


# df_2019_jan['main_category'] = 'no_value'
# cat_loc = df_2019_jan.columns.get_loc('main_category')


# for n in (range(len(df_2019_jan))):
#     if 'parent_id' not in df_2019_jan.iloc[n]['category'].keys():
#         cat_id = df_2019_jan.iloc[n]['category']['id']
#         df_2019_jan.iat[n, cat_loc] = cat_id
#     elif pd.isnull(df_2019_jan.iloc[n]['category']['parent_id']):
#         cat_id = df_2019_jan.iloc[n]['category']['id']
#         df_2019_jan.iat[n, cat_loc] = cat_id
#     else:
#         par_id = df_2019_jan.iloc[n]['category']['parent_id']
#         df_2019_jan.iat[n, cat_loc] = par_id
        
# df_2019_jan['main_category'] = df_2019_jan['main_category'].apply(lambda x: categories_df[x])


# elapsed = timeit.default_timer() - start_time
# print(f'time: {elapsed}')

# df_2019_jan.head(1)

# %%
# # keep these features
# df_main_feats = ['id', 'name', 'blurb', 'goal', 'pledged', 'state', 'country',
# 'currency', 'deadline', 'launched_at', 'staff_pick', 'main_category',
# 'backers_count', 'static_usd_rate', 'usd_pledged' ]
# # Drop these 
# df_drop_feats = list(set(df_2019_jan_cols) - set(df_main_feats))
# print(f'Columns removed: {df_drop_feats}')

# # drop features
# df_2019_jan.drop(df_drop_feats, axis=1, inplace=True)

# %%
# convert unix dates to datetime objects
df_2019_jan.deadline = df_2019_jan.deadline.apply(lambda x: (datetime.fromtimestamp(x)))
df_2019_jan.launched_at = df_2019_jan.launched_at.apply(lambda x: (datetime.fromtimestamp(x)))

# %%
# rename columns
df_2019_jan.rename(columns={'id':'project_id'}, inplace=True)
df_2019_jan.rename(columns={'name':'project_name'}, inplace=True)
df_2019_jan.rename(columns={'blurb':'project_description'}, inplace=True)
df_2019_jan.rename(columns={'state':'outcome_state'}, inplace=True)

# %%
# add project duration feature
df_2019_jan['duration'] = df_2019_jan.deadline - df_2019_jan.launched_at
df_2019_jan['days_from_launch'] =(df_2019_jan_collected_on - df_2019_jan.launched_at).apply(lambda x: x.days)

# # add feature 'in_mid_duration_range' indicating whether project is about halfway through
# df_2019_jan['duration_mid_point'] = df_2019_jan.duration.apply(lambda x: x.days) / 2
# df_2019_jan['lower_bound_mid_point_range'] = df_2019_jan.duration_mid_point.apply(lambda x: x - 5)
# df_2019_jan['upper_bound_mid_point_range'] = df_2019_jan.duration_mid_point.apply(lambda x: x + 5)
# df_2019_jan['in_mid_duration_range'] = df_2019_jan.days_from_launch.between(df_2019_jan.lower_bound_mid_point_range, df_2019_jan.upper_bound_mid_point_range)

# df_2019_jan.drop(['duration_mid_point', 'lower_bound_mid_point_range', 'upper_bound_mid_point_range'], axis=1, inplace=True)

# %%
# df_2019_jan['duration'][0].quantile(.1)
df_2019_jan['duration_10_percent'] = df_2019_jan.duration.apply(lambda x: x.days / 10 )

# %%
# add feature 'in_mid_duration_range' indicating whether project is about halfway through
df_2019_jan['lower_bound'] = df_2019_jan.duration_10_percent.apply(lambda x: x if x < 5 else x - 5)
df_2019_jan['upper_bound'] = df_2019_jan.duration_10_percent.apply(lambda x: x + 5)
df_2019_jan['in_range'] = df_2019_jan.days_from_launch.between(df_2019_jan.lower_bound, df_2019_jan.upper_bound)

# df_2019_jan.drop(['duration_mid_point', 'lower_bound_mid_point_range', 'upper_bound_mid_point_range'], axis=1, inplace=True)

# %%
# calculate usd_goal
df_2019_jan['usd_goal'] = df_2019_jan.goal * df_2019_jan.static_usd_rate

# %%
# Replace goal and rearrange
# col_list = df_2019_jan.columns.to_list()
# print(col_list)
col_list_rearrange = ['project_id', 'project_name', 'project_description', 'outcome_state', 'in_range',
                      'duration_10_percent', 'days_from_launch', 
                      'usd_goal', 'usd_pledged', 'currency', 'launched_at', 'deadline', 'staff_pick', 'country', 
                      'duration' , 'backers_count']
df_2019_jan = df_2019_jan[col_list_rearrange]
df_2019_jan.head(1)
# Out:
#    project_id                                 project_name  \
# 0   320897621  A Date in 2025 - A sci-fi comedy short film
#
#                                  project_description outcome_state  in_range  \
# 0  In the year 2025, a young man's superintellige...    successful     False
#
#    duration_10_percent  days_from_launch  usd_goal usd_pledged currency  \
# 0                  3.0               840    4000.0     5265.82      USD
#
#           launched_at            deadline  staff_pick country duration  \
# 0 2016-09-28 13:05:23 2016-10-28 13:05:23       False      US  30 days
#
#    backers_count
# 0            108

# %%
df_2019_jan_copy = df_2019_jan.copy(deep=True)
# convert datetime columns before exporting
# df_2019_jan.duration = df_2019_jan.duration.apply(lambda x: x.days) 
df_2019_jan.launched_at = df_2019_jan.launched_at.apply(lambda x: x.strftime('%m-%d-%Y'))
df_2019_jan.deadline = df_2019_jan.deadline.apply(lambda x: x.strftime('%m-%d-%Y'))

# %%
# export cleaned dataframe to csv
df_2019_jan.to_csv('clean_datasets_10/main_df_2019_jan.csv', index=False)
